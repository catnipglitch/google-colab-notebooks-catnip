# %% [markdown]
# ## Setup

# %% [markdown]
# ## Install SDK

# %%
# %pip install -U -q google-genai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.9/168.9 kB 4.5 MB/s eta 0:00:00

# %% [markdown]
# ## Setup API key

# %%
from google.colab import userdata

GOOGLE_API_KEY = userdata.get('GOOGLE_API_KEY')

# %% [markdown]
# ### Initialize SDK client

# %%
from google import genai
from google.genai import types
from PIL import Image
from IPython.display import Image, Markdown



client = genai.Client(api_key=GOOGLE_API_KEY)

# %%
MODEL_ID = "gemini-2.0-flash-preview-image-generation" # @param ["gemini-2.0-flash-preview-image-generation","gemini-2.0-flash-lite","gemini-2.0-flash","gemini-2.5-flash-preview-04-17","gemini-2.5-pro-exp-03-25"] {"allow-input":true, isTemplate: true}

# %%
img_text_prompt = "Show me how to bake a macaron with images." # @param {"type":"string"}

# %%
response = client.models.generate_content(
   model=MODEL_ID,
   contents=(
       img_text_prompt
   ),
   config=types.GenerateContentConfig(
        response_modalities=["TEXT", "IMAGE"]
   ),
)


for part in response.candidates[0].content.parts:
  if part.text is not None:
    display(Markdown(part.text))
  elif part.inline_data is not None:
    mime = part.inline_data.mime_type
    print(mime)
    data = part.inline_data.data
    display(Image(data=data))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# @title デフォルトのタイトル テキスト
# @markdown  これはまーくだうん？
# @title デフォルトのタイトル テキスト
# @markdown  これはまーくだうん？
variable_name = False # @param {"type":"boolean"}
variable_name2 = 0 # @param {"type":"number"}
variable_raw = fafadfjalkfjakl; # @param {"type":"raw"}
variable_string = "" # @param {"type":"string"}

## afafa

#### aaa
